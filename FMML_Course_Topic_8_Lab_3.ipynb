# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalyanireddy78/FMML-LAB--1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 03:34:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   154MB/s    in 0.4s
#
# 2024-03-31 03:34:14 (154 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39808  1705.02997v1  Light field cameras have many advantages over ...    cs
# 10340   1209.4115v2  Compensating changes between a subjects' train...  stat
# 17456  1711.04231v1  Attention mechanism, including global attentio...    cs
# 13625   1402.1931v1  Recently there has been many works on adaptive...    cs
# 21796  1604.01075v1  Many retailers today employ inventory manageme...  stat
# ...             ...                                                ...   ...
# 14020  1705.05592v1  Machine learning algorithms are inherently mul...    cs
# 2877   1803.07710v2  A useful computation when acting in a complex ...    cs
# 37082  1606.07533v1  In the last few decades, numerous experiments ...    cs
# 23273   1011.0596v1  Calibration in a multi camera network has wide...    cs
# 40294  1803.04053v1  Accurate prediction of local distortion visibi...    cs
#
#                                                    title  year  \
# 39808  Light Field Video Capture Using a Learning-Bas...  2017
# 10340  Transferring Subspaces Between Subjects in Bra...  2012
# 17456  Syntax-Directed Attention for Neural Machine T...  2017
# 13625  MCA Learning Algorithm for Incident Signals Es...  2014
# 21796  A Dynamic Bayesian Network Model for Inventory...  2016
# ...                                                  ...   ...
# 14020  Ensemble of heterogeneous flexible neural tree...  2017
# 2877   Inference in Probabilistic Graphical Models by...  2018
# 37082  Translucent Players: Explaining Cooperative Be...  2016
# 23273  Multiple View Reconstruction of Calibrated Ima...  2010
# 40294  Learning Local Distortion Visibility From Imag...  2018
#
#                                                 keywords
# 39808  [advantages, traditional, capturing, bandwidth...
# 10340  [compensating, interfacing, challenging, impor...
# 17456  [attention, mechanism, including, attention, a...
# 13625  [filtering, processing, literature, concerned,...
# 21796  [retailers, inventory, management, assumption,...
# ...                                                  ...
# 14020  [algorithms, inherently, multiobjective, appro...
# 2877   [computation, environment, probabilities, vari...
# 37082  [experiments, cooperative, cooperation, partic...
# 23273  [calibration, photogrammetry, presented, calib...
# 40294  [prediction, distortion, visibility, threshold...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39808    [advantages, traditional, capturing, bandwidth...
# 10340    [compensating, interfacing, challenging, impor...
# 17456    [attention, mechanism, including, attention, a...
# 13625    [filtering, processing, literature, concerned,...
# 21796    [retailers, inventory, management, assumption,...
#                                ...
# 22202    [developed, ergodicity, tradition, constraints...
# 5647     [classification, frequently, imbalance, requir...
# 36357    [extracting, wikipedia, experimental, environm...
# 36097    [important, successful, exploitation, importan...
# 6398     [transformations, specified, similarity, dissi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8624 words.
# Out of those 4519 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="da5c53b2-1adf-47f6-834e-b9fc67ebbd97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da5c53b2-1adf-47f6-834e-b9fc67ebbd97")) {                    Plotly.newPlot(                        "da5c53b2-1adf-47f6-834e-b9fc67ebbd97",                        [{"x":["convolutional","estimation","outperforms","achievable","bandwidth","traditional","propagates","appearance","advantages","information","applications","decomposed","capturing","algorithm","interpolation","demonstrate","generation","experimental","infeasible","stationarities","different","subspaces","performance","conceptual","transferring","significant","shrinking","difference","challenging","construct","compensating","invariant","characteristics","importance","operation","covariance","meaningful","interfacing","interpretation","discriminative","recordings","estimated","extracted","important","performing","alignment","architecture","constraints","translation","predicted","syntactically","attention","centering","comparison","improvement","selectively","representation","prediction","effective","substantial","experiments","constraint","mechanism","including","illustrate","corresponding","telecommunications","associated","concerned","technique","presented","filtering","convergence","parameter","application","eigenvector","furnished","determine","parametric","extracting","theoretical","simulation","eigenvalues","extraction","literature","processing","statistical","eigenvalue","component","eigenvectors","performed","distributions","unobserved","inexpensive","inventory","unfortunately","quantities","management","motivated","situations","variables","varieties","discrepancies","expectation","decreases","maximization","interaction","assumption","marketing","dimensional","consequence","parameters","nonlinear","potentials","exhaustive","benchmark","solutions","specifically","exploration","algorithms","stochastic","systematic","instances","applicable","appropriate","diffusion","distribution","modelling","structure","regularisation","complicate","transformations","deterministic","framework","represented","linearisation","preserves","accurately","occurrence","decreasing","architectures","diversity","computation","artifacts","capability","generated","significantly","generators","improving","manipulating","contribution","cooperative","functions","collectively","anonymous","themselves","coalitions","connection","establish","characterized","simultaneous","following","identical","approximation","partition","submodular","approximate","equilibria","approximately","computing","valuation","algorithmic","stability","fractionally","questions","individual","effectiveness","synthetic","treatment","medication","personalized","inference","pointwise","individualized","constructing","localized","counterfactual","operators","particularly","directions","resulting","properties","clustering","uniqueness","established","analogous","persistence","functoriality","multiresolution","persistent"],"y":[383,205,267,6,13,176,4,72,105,704,400,10,42,786,21,544,128,387,7,0,751,19,890,24,19,248,6,57,236,112,0,68,105,88,34,24,45,1,52,97,8,62,118,359,77,55,236,156,113,44,6,158,1,126,138,9,392,243,259,50,599,92,104,263,78,130,2,114,19,253,158,65,113,123,254,4,1,57,39,72,149,70,7,120,117,281,155,5,92,11,126,116,9,7,8,37,19,53,64,55,150,3,5,28,18,27,80,76,10,200,19,235,59,18,13,238,147,188,65,603,108,43,101,54,85,22,218,48,352,4,2,41,34,545,79,1,15,81,35,7,120,47,152,25,49,182,276,6,108,3,82,18,221,8,3,15,3,34,43,34,27,88,17,119,21,11,102,7,41,130,3,31,34,2,57,121,231,114,41,1,10,202,4,2,49,15,8,46,92,41,129,195,134,2,39,13,1,0,4,2],"type":"bar"},{"x":["convolutional","estimation","outperforms","achievable","bandwidth","t ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4519,), (4519, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>Spatially</span> <span style='background-color:rgba(255, 0, 0, 0.45454545454545464);'>Regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>Filters</span> <span style=''>for</span> <span style=''>Visual</span> <span style=''>Tracking</span> <br/><br/><span style=''>Robust</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>visual</span> <span style=''>tracking</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.34857142857142864);'>challenging</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>problems</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>inherent</span> <span style=''>lack</span> <span style=''>of</span> <span style=''>training</span> <span style=''>data</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.9199999999999999);'>appearance</span> <span style=''>model</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>Recently</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>discriminatively</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>filters</span> <span style=''>(DCF)</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>for</span> <span style=''>tracking</span> <span style=''>These</span> <span style=''>methods</span> <span style=''>utilize</span> <span style=''>a</span> <span style=''>periodic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>on</span> <span style=''>all</span> <span style=''>patches</span> <span style=''>in</span> <span style=''>the</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>However</span> <span style=''>the</span> <span style=''>periodic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>unwanted</span> <span style=''>boundary</span> <span style=''>effects</span> <span style=''>which</span> <span style=''>severely</span> <span style=''>degrade</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tracking</span> <span style=''>model</span> <span style=''>We</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>Spatially</span> <span style='background-color:rgba(255, 0, 0, 0.45454545454545464);'>Regularized</span> <span style='background-color:rgba(0, 255, 0, 0.5275590551181102);'>Discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>Filters</span> <span style=''>(SRDCF)</span> <span style=''>for</span> <span style=''>tracking</span> <span style=''>A</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Confounder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Linear</span> <span style=''>Models</span> <span style=''>using</span> <span style=''>First</span> <span style=''>Moments</span> <span style=''>of</span> <span style=''>Spectral</span> <span style=''>Measures</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounder</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>where</span> <span style=''>the</span> <span style=''>target</span> <span style=''>variable</span> <span style=''>Y</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>using</span> <span style=''>its</span> <span style=''>n</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>causes</span> <span style=''>X</span> <span style=''>n(x</span> <span style=''>1x</span> <span style=''>n)T</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>rotation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>process</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>recent</span> <span style=''>study</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>measure</span> <span style=''>induced</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficient</span> <span style=''>vector</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>X</span> <span style=''>n</span> <span style=''>is</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>uniform</span> <span style=''>measure</span> <span style=''>in</span> <span style=''>purely</span> <span style=''>causal</span> <span style=''>cases</span> <span style=''>but</span> <span style=''>it</span> <span style=''>differs</span> <span style=''>from</span> <span style=''>a</span> <span style=''>uniform</span> <span style=''>measure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characteristically</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>scalar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounder</span> <span style=''>Then</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>spectral</span> <span style=''>measure</span> <span style=''>pattern</span> <span style=''>could</span> <span style=''>help</span> <span style=''>to</span> <span style=''>detect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounding</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Regularizers</span> <span style=''>versus</span> <span style=''>Losses</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <span style=''>A</span> <span style=''>Factored</span> <span style=''>View</span> <span style=''>with</span> <span style=''>New</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relaxations</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.42647058823529416);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style='background-color:rgba(255, 0, 0, 0.45454545454545464);'>regularized</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>plus</span> <span style=''>singular</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>truncation</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguishing</span> <span style=''>the</span> <span style=''>role</span> <span style=''>of</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>in</span> <span style=''>such</span> <span style=''>a</span> <span style=''>process</span> <span style=''>we</span> <span style=''>recover</span> <span style=''>a</span> <span style=''>factored</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>that</span> <span style=''>reveals</span> <span style=''>some</span> <span style=''>gaps</span> <span style=''>in</span> <span style=''>the</span> <span style=''>current</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>Beyond</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>a</span> <span style=''>useful</span> <span style=''>new</span> <span style=''>loss</span> <span style=''>for</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unfolding</span> <span style=''>a</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.32258064516129026);'>contribution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>new</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizers</span> <span style=''>that</span> <span style=''>combine</span> <span style=''>distance</span> <span style='background-color:rgba(255, 0, 0, 0.425531914893617);'>maximization</span> <span style=''>with</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizers</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>any</span> <span style=''>loss</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Panoramic</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Foreground</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Background</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separation</span> <span style=''>on</span> <span style=''>Noisy</span> <span style=''>Free</span> <span style=''>Motion</span> <span style=''>Camera</span> <span style=''>Video</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>with</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foreground</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>background</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style=''>on</span> <span style=''>noisy</span> <span style=''>moving</span> <span style=''>camera</span> <span style=''>video</span> <span style=''>Our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>registers</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>(possibly</span> <span style=''>corrupted)</span> <span style=''>frames</span> <span style=''>of</span> <span style=''>a</span> <span style=''>video</span> <span style=''>and</span> <span style=''>then</span> <span style=''>jointly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>registered</span> <span style=''>frames</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>scene</span> <span style=''>into</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>background</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>that</span> <span style=''>captures</span> <span style=''>the</span> <span style=''>static</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style=''>the</span> <span style=''>scene</span> <span style=''>a</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foreground</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>that</span> <span style=''>captures</span> <span style=''>the</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style=''>the</span> <span style=''>scene</span> <span style=''>and</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>that</span> <span style=''>isolates</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corruptions</span> <span style=''>Unlike</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>produces</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>panoramic</span> <span style=''>low< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07257203842049093)
# 	experimental (0.1376734258271078)
# 	segmentation (0.06865884027036642)
# 	architecture (0.0839558875844895)
# 	representation (0.13945215225898258)
# 	information (0.2504446816079687)
# 	detection (0.12415510494485948)
# 	different (0.2671647100675916)
# 	convolutional (0.13625044468160796)
# 	recognition (0.1326929918178584)
#
# Some Statistics words are:
# 	optimization (0.1870286576168929)
# 	theoretical (0.15082956259426847)
# 	statistical (0.15384615384615385)
# 	stochastic (0.13976872800402212)
# 	estimation (0.1779788838612368)
# 	algorithm (0.38712921065862244)
# 	distribution (0.18652589240824535)
# 	dimensional (0.1870286576168929)
# 	inference (0.20361990950226244)
# 	regression (0.1895424836601307)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="de2e0467-88dc-4ba9-b8af-847ebe9cb7b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de2e0467-88dc-4ba9-b8af-847ebe9cb7b7")) {                    Plotly.newPlot(                        "de2e0467-88dc-4ba9-b8af-847ebe9cb7b7",                        [{"x":["convolutional","estimation","outperforms","achievable","bandwidth","traditional","propagates","appearance","advantages","information","applications","decomposed","capturing","algorithm","interpolation","demonstrate","generation","experimental","infeasible","stationarities","different","subspaces","performance","conceptual","transferring","significant","shrinking","difference","challenging","construct","compensating","invariant","characteristics","importance","operation","covariance","meaningful","interfacing","interpretation","discriminative","recordings","estimated","extracted","important","performing","alignment","architecture","constraints","translation","predicted","syntactically","attention","centering","comparison","improvement","selectively","representation","prediction","effective","substantial","experiments","constraint","mechanism","including","illustrate","corresponding","telecommunications","associated","concerned","technique","presented","filtering","convergence","parameter","application","eigenvector","furnished","determine","parametric","extracting","theoretical","simulation","eigenvalues","extraction","literature","processing","statistical","eigenvalue","component","eigenvectors","performed","distributions","unobserved","inexpensive","inventory","unfortunately","quantities","management","motivated","situations","variables","varieties","discrepancies","expectation","decreases","maximization","interaction","assumption","marketing","dimensional","consequence","parameters","nonlinear","potentials","exhaustive","benchmark","solutions","specifically","exploration","algorithms","stochastic","systematic","instances","applicable","appropriate","diffusion","distribution","modelling","structure","regularisation","complicate","transformations","deterministic","framework","represented","linearisation","preserves","accurately","occurrence","decreasing","architectures","diversity","computation","artifacts","capability","generated","significantly","generators","improving","manipulating","contribution","cooperative","functions","collectively","anonymous","themselves","coalitions","connection","establish","characterized","simultaneous","following","identical","approximation","partition","submodular","approximate","equilibria","approximately","computing","valuation","algorithmic","stability","fractionally","questions","individual","effectiveness","synthetic","treatment","medication","personalized","inference","pointwise","individualized","constructing","localized","counterfactual","operators","particularly","directions","resulting","properties","clustering","uniqueness","established","analogous","persistence","functoriality","multiresolution","persistent","existence","kleinberg","psychology","foundations","judgments","disjunctions","cognitive","systematically","operational","combinations","formalism","membership","particular","mathematical","phenomena","dependence","responsible","structures","explaining","extension","interfere","conjunctions","interference","classical","deviations","axiomatic","economical","linguistic","naturally","minimalist","practical","belonging","mechanics","difficult","resembles","presentation","otherwise","relations","syntactic","sentences","background","linguistics","motivating","canonical","likelihood","neighborhood","graphical","estimates","hierarchical","distributed","likelihoods","relaxation","considering","asymptotic","consistent","symmetri ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	stationarities
# 	compensating
# 	functoriality
# 	kleinberg
# 	staleness
# 	modulation
# 	unverifiable
# 	integrator
# 	blockwise
# 	substituting
# 	interdisciplinary
# 	inhibited
# 	bivariate
# 	factorizes
# 	textitnot
# 	nonadaptive
# 	nonconjugate
# 	thermodynamics
# 	tailoring
# 	nonparametrics
# Some words which never appear in Statistics papers:
# 	syntactically
# 	telecommunications
# 	coalitions
# 	valuation
# 	fractionally
# 	disjunctions
# 	interfere
# 	conjunctions
# 	economical
# 	minimalist
# 	syntactic
# 	explosive
# 	governmental
# 	subjectivity
# 	synergetic
# 	hybridization
# 	favourable
# 	pathological
# 	successor
# 	spontaneously

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.064758343804591e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
